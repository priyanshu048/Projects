# %%
# import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize']= (12,8) #adjusts config. of plots we'll create

# %%
# Reading the data

df = pd.read_csv('C:\\Users\\Priyanshu\\Downloads\\archive\\movies.csv')

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# check for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.0%
# gross - 0.0%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# replacing the 0 values with mean in 'budget' and 'gross' columns
budget_mean = df['budget'].mean()
gross_mean = df['gross'].mean()
df['budget'].fillna(budget_mean, inplace=True)
df['gross'].fillna(gross_mean, inplace=True)
df['budget'].replace(0, budget_mean, inplace=True)
df['gross'].replace(0, gross_mean, inplace=True)

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#change datatype of columns

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

# %%
#  extracting year from 'release' column

# Convert 'released' column to string type
df['released'] = df['released'].astype(str)

# Find the index of the comma in each string
df['comma_idx'] = df['released'].str.find(',')

# Extract the year from each string
df['yearcorrect'] = df.apply(lambda row: row['released'][row['comma_idx'] + 2 : row['comma_idx'] + 6], axis=1)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 3818                        Love, Honor and Obey          R  Comedy  2000
# 7625                            The Untold Story        NaN  Comedy  2019
# 7580                         Run with the Hunted  Not Rated   Crime  2019
# 2417                                    Madadayo        NaN   Drama  1993
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes         director  \
# ...

# %%
# Budget high correlation
# Company high correlation

# %%
#scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')
plt.ylabel('Budget')

plt.show()

# %%
# Plot budget vs gross using seaborn
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'purple'}, line_kws={'color':'blue'})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime', 'comma_idx', 'yearcorrect'],
#       dtype='object')

# %%
# Looking at correlation:
numeric_df = df.drop(columns=['name', 'rating', 'genre', 'released',
                              'director','writer', 'star','comma_idx',
                              'country','company'])
numeric_df.corr()
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.100367  0.220799  0.265587  0.250701  0.120469
# score        0.100367  1.000000  0.411208  0.064408  0.184146  0.400263
# votes        0.220799  0.411208  1.000000  0.421025  0.628328  0.309171
# budget       0.265587  0.064408  0.421025  1.000000  0.711627  0.265277
# gross        0.250701  0.184146  0.628328  0.711627  1.000000  0.241454
# runtime      0.120469  0.400263  0.309171  0.265277  0.241454  1.000000
# yearcorrect  0.255493  0.030248  0.068090  0.075228  0.070851  0.033493
#
#              yearcorrect
# year            0.255493
# score           0.030248
# votes           0.068090
# budget          0.075228
# gross           0.070851
# runtime         0.033493
# yearcorrect     1.000000

# %%
# budget' has a strong positive correlation with 'gross',
#indicating that movies with higher budgets tend to earn higher gross revenues.

# %%
correlation_matrix = numeric_df.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation matrix ')

plt.xlabel('Movie Features')
plt.ylabel('Budget for film')

plt.show()

# %%
df_numerized = df.copy()

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6543       6      6  1980      1690    8.4   927000.0      2584    4000
# 1  5536       6      1  1980      1477    5.8    65000.0      2264    1625
# 2  5108       4      0  1980      1753    8.7  1200000.0      1108    2559
# 3   285       4      4  1980      1477    7.7   221000.0      1298    1993
# 4  1024       6      4  1980      1528    7.3   108000.0      1051     519
#
#    star  country    budget      gross  company  runtime  comma_idx  \
# 0  1038       54  19000000   46998772     2302    146.0          7
# 1   323       55   4500000   58853106      726    104.0          6
# 2  1729       55  18000000  538375067     1528    124.0          7
# 3  2222       55   3500000   83453539     1799     88.0          6
# 4   406       55   6000000   39846344     1764     98.0          7
#
#    yearcorrect
# 0            2
# 1            2
# 2            2
# 3            2
# 4            2

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
correlation_matrix = df_numerized.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation matrix ')

plt.xlabel('Movie Features')
plt.ylabel('Budget for film')

plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.010480
#                               ...
# yearcorrect  gross          0.229416
#              company       -0.028547
#              runtime        0.111354
#              comma_idx     -0.095175
#              yearcorrect    1.000000
# Length: 289, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs.head()
# Out:
# budget  genre    -0.310566
# genre   budget   -0.310566
#         gross    -0.230267
# gross   genre    -0.230267
# votes   genre    -0.145307
# dtype: float64

# %%
pd.set_option('display.max_rows', None)

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr.head()
# Out:
# votes   gross          0.628713
# gross   votes          0.628713
#         budget         0.711270
# budget  gross          0.711270
# year    yearcorrect    0.944769
# dtype: float64

# %%
# votes and budget have the highest correlation to gross earnings
